# %%
import pandas as pd, matplotlib.pyplot as plt,seaborn as sns

# %%
data=pd.read_csv("netflix_titles.csv")
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %%
data.columns #Columns that are present in dataset
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
data['director']
# Out:
# 0       Kirsten Johnson
# 1                   NaN
# 2       Julien Leclercq
# 3                   NaN
# 4                   NaN
#              ...
# 8802      David Fincher
# 8803                NaN
# 8804    Ruben Fleischer
# 8805       Peter Hewitt
# 8806        Mozez Singh
# Name: director, Length: 8807, dtype: object

# %%
column=data['type']
value_counts = column.value_counts()
labels = [f'{index}: {value_counts[index]}' for index in value_counts.index]
plt.pie(column.value_counts(),labels=labels)
plt.show()

# %%
netflix=data.dropna()
movie=movie = netflix[netflix['type'] == 'Movie']
movie['duration'] = movie['duration'].str.replace(' min', '').astype(int)
plt.scatter(movie['release_year'], movie['duration'],color="pink")

# Add labels and title
plt.xlabel('Release Year')
plt.ylabel('Duration')
plt.title('Scatter Plot of Release Year vs. Duration')

# Display the plot
plt.show()
# Out:
# C:\Users\ABHINANDAN\AppData\Local\Temp\ipykernel_5584\11867933.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie['duration'] = movie['duration'].str.replace(' min', '').astype(int)

# %%
# Find the index of the row with the minimum duration
min_duration_index = movie['duration'].idxmin()

# Get the corresponding release year and duration
corresponding_min_release_year = movie.loc[min_duration_index, 'release_year']
min_duration = movie.loc[min_duration_index, 'duration']

print(f"The movie with the minimum duration of {min_duration} minutes was released in the year {corresponding_min_release_year}.")

# Find the index of the row with the maximum duration
max_duration_index = movie['duration'].idxmax()

# Get the corresponding release year and duration
corresponding_max_release_year = movie.loc[max_duration_index, 'release_year']
max_duration = movie.loc[max_duration_index, 'duration']

print(f"The movie with the maximum duration of {max_duration} minutes was released in the year {corresponding_max_release_year}.")
# Out:
# The movie with the minimum duration of 8 minutes was released in the year 2020.
# The movie with the maximum duration of 253 minutes was released in the year 1973.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file into a DataFrame
data = pd.read_csv('netflix_titles.csv')

# Specify the column to plot
column_name = 'type'

# Count the occurrences of each value in the specified column
value_counts = data[column_name].value_counts()

# Plot the bar chart
plt.figure(figsize=(8, 6))  # Adjust the figure size if needed
value_counts.plot(kind='bar', color='skyblue')

# Add title and labels
plt.title('Distribution of Shows and Movies on Netflix')
plt.xlabel('Type')
plt.ylabel('Count')

# Show the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
data = pd.read_csv("netflix_titles.csv")

# Count the occurrences of each rating
rating_counts = data['rating'].value_counts()

# Plotting a pie chart
plt.figure(figsize=(8, 8))
rating_counts.plot(kind='pie', autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Movie/TV Show Ratings on Netflix')
plt.ylabel('')  # Remove y-axis label
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have already processed the data as you mentioned in your previous code

# Create a scatter plot of genre counts
plt.figure(figsize=(10, 6))
plt.scatter(genre_counts_movie['genre'], genre_counts_movie['count'], color='skyblue')
plt.xlabel('Genres')
plt.ylabel('Count')
plt.title('Count of Movie Genres')
plt.xticks(rotation=90)
plt.show()

# %%
movie['genres'] = movie['listed_in'].str.extract('([A-Z]\w{2,})', expand=True)

# Count the occurrences of each genre
genre_counts_movie = movie['genres'].value_counts().reset_index()

# Rename the columns to 'genre' and 'count'
genre_counts_movie.columns = ['genre', 'count']

# Create a bar plot of genre counts
plt.figure(figsize=(10, 6))
plt.bar(genre_counts_movie['genre'], genre_counts_movie['count'], color='skyblue')
plt.xlabel('Genres')
plt.ylabel('Count')
plt.title('Count of Movie Genres')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\ABHINANDAN\AppData\Local\Temp\ipykernel_5584\2941162454.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie['genres'] = movie['listed_in'].str.extract('([A-Z]\w{2,})', expand=True)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have already computed value counts for the 'type' column
# value_counts variable should be available from the previous code

# Sort the value counts by index
sorted_counts = value_counts.sort_index()

# Create a line chart of value counts
plt.figure(figsize=(10, 6))
plt.plot(sorted_counts.index, sorted_counts.values, marker='o', color='skyblue', linestyle='-')
plt.xlabel('Type')
plt.ylabel('Count')
plt.title('Distribution of Types')
plt.xticks(rotation=45, ha='right')
plt.grid(True)  # Add grid lines for better readability
plt.show()
